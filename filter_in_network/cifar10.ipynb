# %% [markdown]
# ## Training model for CIFAR10

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from keras.models import Sequential, load_model
from keras.datasets import cifar10
from keras.utils import np_utils
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.callbacks import ModelCheckpoint

# %%
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
x_train = X_train.astype('float32')/255
x_test = X_test.astype('float32')/255
y_train = np_utils.to_categorical(Y_train)
y_test = np_utils.to_categorical(Y_test)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step

# %%
model = Sequential()
model.add(Conv2D(filters=64, kernel_size=3, input_shape=(32, 32, 3), activation='relu', padding='same'))
model.add(Conv2D(filters=64, kernel_size=3, input_shape=(32, 32, 3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=2))

model.add(Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'))
model.add(Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=2))

model.add(Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'))
model.add(Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=2))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(rate=0.25))
model.add(Dense(10, activation='softmax'))

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         147584
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,609,546
# Trainable params: 1,609,546
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model_checkpoint = ModelCheckpoint('drive/MyDrive/class_Image/HW4/model.hdf5', monitor='val_loss', verbose=1, save_best_only=False)
model.fit(x_train, y_train, epochs=10, batch_size=64, verbose=1, callbacks=[model_checkpoint])
# Out:
# Epoch 1/10
# 781/782 [============================>.] - ETA: 0s - loss: 0.1292 - accuracy: 0.9576
# Epoch 00001: saving model to drive/MyDrive/class_Image/HW4/model.hdf5
# 782/782 [==============================] - 24s 29ms/step - loss: 0.1292 - accuracy: 0.9576
# Epoch 2/10
# 781/782 [============================>.] - ETA: 0s - loss: 0.1168 - accuracy: 0.9607
# Epoch 00002: saving model to drive/MyDrive/class_Image/HW4/model.hdf5
# 782/782 [==============================] - 22s 29ms/step - loss: 0.1169 - accuracy: 0.9607
# Epoch 3/10
# 781/782 [============================>.] - ETA: 0s - loss: 0.1125 - accuracy: 0.9620
# Epoch 00003: saving model to drive/MyDrive/class_Image/HW4/model.hdf5
# 782/782 [==============================] - 22s 29ms/step - loss: 0.1126 - accuracy: 0.9620
# Epoch 4/10
# 781/782 [============================>.] - ETA: 0s - loss: 0.1170 - accuracy: 0.9609
# Epoch 00004: saving model to drive/MyDrive/class_Image/HW4/model.hdf5
# 782/782 [==============================] - 22s 29ms/step - loss: 0.1170 - accuracy: 0.9609
# Epoch 5/10
# 781/782 [============================>.] - ETA: 0s - loss: 0.1147 - accuracy: 0.9622
# Epoch 00005: saving model to drive/MyDrive/class_Image/HW4/model.hdf5
# 782/782 [==============================] - 22s 29ms/step - loss: 0.1146 - accuracy: 0.9622
# Epoch 6/10
# 781/782 [============================>.] - ETA: 0s - loss: 0.1096 - accuracy: 0.9637
# Epoch 00006: saving model to drive/MyDrive/class_Image/HW4/model.hdf5
# 782/782 [==============================] - 22s 29ms/step - loss: 0.1098 - accuracy: 0.9637
# Epoch 7/10
# 781/782 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9618
# Epoch 00007: saving model to drive/MyDrive/class_Image/HW4/model.hdf5
# 782/782 [==============================] - 22s 29ms/step - loss: 0.1177 - accuracy: 0.9618
# Epoch 8/10
# 781/782 [============================>.] - ETA: 0s - loss: 0.1058 - accuracy: 0.9650
# Epoch 00008: saving model to drive/MyDrive/class_Image/HW4/model.hdf5
# 782/782 [==============================] - 22s 29ms/step - loss: 0.1057 - accuracy: 0.9650
# Epoch 9/10
# 781/782 [============================>.] - ETA: 0s - loss: 0.1062 - accuracy: 0.9656
# Epoch 00009: saving model to drive/MyDrive/class_Image/HW4/model.hdf5
# 782/782 [==============================] - 22s 29ms/step - loss: 0.1062 - accuracy: 0.9656
# Epoch 10/10
# 781/782 [============================>.] - ETA: 0s - loss: 0.1123 - accuracy: 0.9629
# Epoch 00010: saving model to drive/MyDrive/class_Image/HW4/model.hdf5
# 782/782 [==============================] - 22s 29ms/step - loss: 0.1123 - accuracy: 0.9629

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print('Test:')
print('Loss:', loss)
print('Accuracy:', accuracy)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 1.3406 - accuracy: 0.7778
# Test:
# Loss: 1.340636134147644
# Accuracy: 0.7778000235557556

# %% [markdown]
# ## Get three kernels from model after training

# %%
from keras.models import load_model

model = load_model('drive/MyDrive/class_Image/HW4/model.hdf5')

# %% [markdown]
# #### layer 0

# %%
layer_num = 0

# %%
all_kernels, biases = model.layers[layer_num].get_weights()
print(all_kernels.shape)
print(biases.shape)
# Out:
# (3, 3, 3, 64)
# (64,)

# %%
import random

chosen_kernels = []

for i in range(20):
  chosen_kernels.append( all_kernels[:,:,:,i] )

for i in range(len(chosen_kernels)):
  print(i)
  print(chosen_kernels[i])
  print()
# Out:
# [[[ 0.00497072 -0.15258037 -0.22455686]
#   [-0.07347262 -0.16462183 -0.17328459]
#   [-0.0617498  -0.10344191 -0.11840715]]
#
#  [[ 0.09040552  0.1244745   0.0197518 ]
#   [ 0.08187189  0.12061322 -0.03591486]
#   [-0.04829563  0.06485029 -0.10978864]]
#
#  [[-0.2929674  -0.31493354 -0.10019614]
#   [-0.3002111  -0.23391756 -0.30247512]
#   [-0.22419527 -0.36716744 -0.29111245]]]
#
# [[[ 0.11288493  0.06821454 -0.11600643]
#   [ 0.10795915  0.05834523 -0.14704402]
#   [-0.06678109 -0.08439957  0.02054661]]
#
#  [[ 0.14067578  0.11870353 -0.07217357]
#   [ 0.11805544  0.09222941 -0.17893292]
#   [-0.27118772 -0.17238733 -0.03275371]]
#
#  [[ 0.10878824  0.07363927 -0.13982593]
#   [ 0.05689394 -0.09578826 -0.10648343]
#   [-0.17133461 -0.23263107  0.02885778]]]
#
# [[[-0.20507862 -0.01460768 -0.06313529]
#   [-0.10182933 -0.10870101 -0.14355801]
#   [-0.1580708  -0.09349517  0.01773739]]
#
#  [[-0.05939748  0.04606272 -0.17162701]
#   [-0.14962664 -0.10699771 -0.24714138]
#   [ 0.02964118  0.02605474 -0.02934928]]
#
#  [[ 0.07948337  0.09424638  0.02213852]
#   [ 0.02630788  0.03551124 -0.1358671 ]
#   [-0.08758529 -0.03544089 -0.14513792]]]
#
# [[[-0.03979357  0.0245437   0.01935763]
#   [-0.1831574  -0.17377156 -0.13121702]
#   [ 0.00711897 -0.02863978 -0.08351043]]
#
#  [[-0.17358018 -0.03716421 -0.12622508]
#   [-0.13782936 -0.09153719 -0.2986823 ]
#   [ 0.04964095 -0.04103544  0.0481605 ]]
#
#  [[ 0.04122082  0.07442909 -0.05369681]
#   [-0.01289927  0.05068869 -0.13799483]
#   [ 0.12455826  0.14134713  0.07852209]]]
#
# [[[-0.02158356 -0.1283726   0.11222156]
#   [ 0.07257495 -0.15818587 -0.11886664]
#   [ 0.12782894 -0.09724934 -0.15643309]]
#
#  [[-0.16215363 -0.09856986  0.07298518]
#   [ 0.110598   -0.15297827  0.05372813]
#   [ 0.19445005 -0.08375585 -0.12285665]]
#
#  [[-0.18588215  0.01028094  0.17001851]
#   [-0.27602822 -0.31049898 -0.24663746]
#   [ 0.15716347  0.11973556  0.08803432]]
#
#  [[-0.07909378  0.07315395  0.08873312]
#   [-0.16853344 -0.11263401 -0.17988864]
#   [-0.16581382 -0.15729465 -0.03178962]]]
#
# [[[-0.18139873 -0.09482674 -0.14679849]
#   [-0.16012487 -0.09389379 -0.11466648]
#   [-0.00551788  0.0413217  -0.0070833 ]]
#
#  [[-0.16915067 -0.10437466 -0.1078015 ]
#   [ 0.01619436 -0.0270555  -0.22155036]
#   [ 0.07043892 -0.11328209  0.03771777]]
#
#  [[ 0.08223528  0.03253124 -0.09264504]
#   [-0.05990181 -0.08709355 -0.17341915]
#   [ 0.01580386 -0.01455681 -0.10644814]]]

# %%
import cv2
import numpy as np
from pathlib import Path

COLOR = 3
KERNEL_SIZE = 3

# read image
origin_img = cv2.imread( 'drive/MyDrive/class_Image/HW4/images/cupcake.jpg' )

# convolution
height = origin_img.shape[0]
width = origin_img.shape[1]

cov_imgs = np.zeros( [ len(chosen_kernels), height+4, width+4, 3 ]) # add padding

cov_range = int((KERNEL_SIZE-1)/2)
for i in range(len(chosen_kernels)):
  kernel = chosen_kernels[i]
  for y in range(cov_range, height-cov_range):
      for x in range(cov_range, width-cov_range):
          part_img = origin_img[ y-1:y+2, x-1:x+2, : ]
          for color in range(0, COLOR):
              value = abs(np.sum(part_img[:,:,color] * kernel[:,:,color]))
              cov_imgs[i,y,x,color] = value
  print('covolution : kernel', i, 'done.')

cov_imgs = cov_imgs[:, KERNEL_SIZE-1:-(KERNEL_SIZE-1), KERNEL_SIZE-1:-(KERNEL_SIZE-1),:] # remove padding

# write convolution images
output_dir = Path.cwd() / 'drive/MyDrive/class_Image/HW4/images/output_img'
Path.mkdir( output_dir, exist_ok=True)

for i in range(cov_imgs.shape[0]):
  cv2.imwrite( str(output_dir)+'/kernel_'+str(layer_num)+'_'+str(i)+'.jpg', cov_imgs[i] )

print('save images done.')
# Out:
# covolution : kernel 0 done.
# covolution : kernel 1 done.
# covolution : kernel 2 done.
# covolution : kernel 3 done.
# covolution : kernel 4 done.
# covolution : kernel 5 done.
# covolution : kernel 6 done.
# covolution : kernel 7 done.
# covolution : kernel 8 done.
# covolution : kernel 9 done.
# covolution : kernel 10 done.
# covolution : kernel 11 done.
# covolution : kernel 12 done.
# covolution : kernel 13 done.
# covolution : kernel 14 done.
# covolution : kernel 15 done.
# covolution : kernel 16 done.
# covolution : kernel 17 done.
# covolution : kernel 18 done.
# covolution : kernel 19 done.
# save images done.

# %% [markdown]
# #### layer 0 -grey

# %%
layer_num = 0

# %%
all_kernels, biases = model.layers[layer_num].get_weights()
print(all_kernels.shape)
print(biases.shape)
# Out:
# (3, 3, 3, 64)
# (64,)

# %%
import random

chosen_kernels = []

for i in range(10,20):
  chosen_kernels.append( all_kernels[:,:,:,i] )

for i in range(len(chosen_kernels)):
  print(i)
  print(chosen_kernels[i])
  print()
# Out:
# 0
# [[[-0.10847659 -0.07223421 -0.04077852]
#   [-0.05441006  0.0128111  -0.03104441]
#   [-0.03458859 -0.05456475  0.02603482]]
#
#  [[ 0.01130721 -0.07016428  0.02272065]
#   [ 0.01883971 -0.02989899 -0.01811647]
#   [-0.08763019  0.03085222  0.01218058]]
#
#  [[-0.07497621 -0.10924009 -0.05030665]
#   [-0.02776211  0.00076088  0.02215889]
#   [-0.10188843  0.03484473 -0.0894475 ]]]
#
# 1
# [[[-0.01931943 -0.04688984 -0.0637237 ]
#   [-0.03205682 -0.07354354 -0.08076991]
#   [-0.06495786  0.03823904 -0.06192773]]
#
#  [[-0.04728746 -0.02411581  0.04780945]
#   [ 0.00409489 -0.17048438  0.02278068]
#   [ 0.02378267 -0.04610307 -0.1119182 ]]
#
#  [[-0.10879003  0.03451513 -0.07002791]
#   [ 0.00432815  0.00261283 -0.07033987]
#   [ 0.02832262 -0.13432173 -0.1039389 ]]]
#
# 2
# [[[-0.09396089 -0.04256    -0.02652537]
#   [ 0.07365009  0.03540148  0.12019425]
#   [-0.00322518 -0.15626624 -0.20164126]]
#
#  [[-0.1277812  -0.11958694  0.08720494]
#   [ 0.30158237  0.18601039  0.38110244]
#   [ 0.09091933 -0.16940206  0.07611309]]
#
#  [[ 0.04854676  0.01276308  0.00621112]
#   [ 0.08483079 -0.14061148  0.10743845]
#   [-0.07525924 -0.12966774 -0.04779052]]]
#
# 3
# [[[-0.06920794  0.02774836  0.02726939]
#   [-0.01528224 -0.10351197  0.04369023]
#   [-0.0013583   0.00306235  0.01657066]]
#
#  [[-0.22527404 -0.21793076 -0.12617806]
#   [-0.201514   -0.15741052  0.01659558]
#   [-0.07700673 -0.02952997  0.02800145]]
#
#  [[ 0.00322307 -0.10507549  0.08293127]
#   [-0.17957203 -0.16714512 -0.10623408]
#   [-0.16614807 -0.05467432  0.08314376]]]
#
# 4
# [[[-0.05579031 -0.09260833  0.03058815]
#   [-0.07754806 -0.06887192 -0.05841857]
#   [-0.02858697 -0.08235943  0.00468653]]
#
#  [[-0.03112612  0.00473817 -0.07941336]
#   [-0.00417069 -0.10561506 -0.05078817]
#   [-0.05615676 -0.11794521 -0.0770493 ]]
#
#  [[-0.13304828 -0.06962692  0.05169377]
#   [-0.0406585   0.01416228  0.04550303]
#   [ 0.00465584 -0.12538569 -0.04638532]]]
#
# 5
# [[[-0.0905098   0.08216272  0.09812605]
#   [-0.13294345 -0.02853168  0.09247562]
#   [-0.14610706  0.12006322 -0.00804621]]
#
#  [[ 0.00136321  0.03412059 -0.07162589]
#   [ 0.09288899  0.20092998  0.12006102]
#   [ 0.02896274  0.17139319  0.12475472]]
#
#  [[-0.16691235 -0.06908619 -0.08346392]
#   [-0.10663199 -0.06510599 -0.013961  ]
#   [-0.16531539 -0.02578286 -0.00232915]]]
#
# 6
# [[[-0.03605135  0.10980169  0.02023563]
#   [-0.03122661  0.07302041 -0.16587286]
#   [-0.08814885  0.00709436 -0.17630559]]
#
#  [[-0.08763795  0.05092124 -0.05548362]
#   [ 0.10558332  0.18077242 -0.19402002]
#   [ 0.02493623  0.15299533 -0.11765694]]
#
#  [[-0.11768064  0.11104802 -0.0863646 ]
#   [ 0.13950719  0.17562291 -0.02524955]
#   [ 0.11338831  0.07253888 -0.14422134]]]
#
# 7
# [[[-0.10162988 -0.02429305 -0.05779799]
#   [ 0.08647857  0.02698902 -0.01657925]
#   [-0.02210969 -0.08391418 -0.16799231]]
#
#  [[-0.00148802 -0.14933087 -0.1819656 ]
#   [-0.2545329  -0.25540885 -0.25323895]
#   [-0.20055833 -0.16411084 -0.14225274]]
#
#  [[-0.03606811  0.08095236  0.0991309 ]
#   [-0.17293003 -0.10922136  0.04333605]
#   [ 0.06281566  0.04916805  0.07327633]]]
#
# 8
# [[[-0.07646652 -0.1585664  -0.03114894]
#   [-0.07201139 -0.14652996 -0.20285301]
#   [ 0.07239548 -0.13222846 -0.21500938]]
#
#  [[-0.06730697 -0.00146918  0.01328807]
#   [-0.27602822 -0.31049898 -0.24663746]
#   [ 0.15716347  0.11973556  0.08803432]]
#
#  [[-0.07909378  0.07315395  0.08873312]
#   [-0.16853344 -0.11263401 -0.17988864]
#   [-0.16581382 -0.15729465 -0.03178962]]]
#
# 9
# [[[-0.18139873 -0.09482674 -0.14679849]
#   [-0.16012487 -0.09389379 -0.11466648]
#   [-0.00551788  0.0413217  -0.0070833 ]]
#
#  [[-0.16915067 -0.10437466 -0.1078015 ]
#   [ 0.01619436 -0.0270555  -0.22155036]
#   [ 0.07043892 -0.11328209  0.03771777]]
#
#  [[ 0.08223528  0.03253124 -0.09264504]
#   [-0.05990181 -0.08709355 -0.17341915]
#   [ 0.01580386 -0.01455681 -0.10644814]]]

# %%
import cv2
import numpy as np
from pathlib import Path

COLOR = 3
KERNEL_SIZE = 3

# read image
origin_img = cv2.imread( 'drive/MyDrive/class_Image/HW4/images/cupcake.jpg' )

# convolution
height = origin_img.shape[0]
width = origin_img.shape[1]

cov_imgs = np.zeros( [ len(chosen_kernels), height+4, width+4, 3 ]) # add padding

cov_range = int((KERNEL_SIZE-1)/2)
for i in range(len(chosen_kernels)):
  kernel = chosen_kernels[i]
  for y in range(cov_range, height-cov_range):
      for x in range(cov_range, width-cov_range):
          part_img = origin_img[ y-1:y+2, x-1:x+2, : ]
          for color in range(0, COLOR):
              value = abs(np.sum(part_img[:,:,color] * kernel[:,:,color]))
              cov_imgs[i,y,x,color] = value
  print('covolution : kernel', i, 'done.')

cov_imgs = cov_imgs[:, KERNEL_SIZE-1:-(KERNEL_SIZE-1), KERNEL_SIZE-1:-(KERNEL_SIZE-1),:] # remove padding

# write convolution images
output_dir = Path.cwd() / 'drive/MyDrive/class_Image/HW4/images/output_img'
Path.mkdir( output_dir, exist_ok=True)

for i in range(cov_imgs.shape[0]):
  cv2.imwrite( str(output_dir)+'/kernel_'+str(layer_num)+'_grey0_'+str(i)+'.jpg', cov_imgs[i,:,:,0] )
  cv2.imwrite( str(output_dir)+'/kernel_'+str(layer_num)+'_grey1_'+str(i)+'.jpg', cov_imgs[i,:,:,1] )
  cv2.imwrite( str(output_dir)+'/kernel_'+str(layer_num)+'_grey2_'+str(i)+'.jpg', cov_imgs[i,:,:,2] )

print('save images done.')
# Out:
# covolution : kernel 0 done.
# covolution : kernel 1 done.
# covolution : kernel 2 done.
# covolution : kernel 3 done.
# covolution : kernel 4 done.
# covolution : kernel 5 done.
# covolution : kernel 6 done.
# covolution : kernel 7 done.
# covolution : kernel 8 done.
# covolution : kernel 9 done.
# save images done.
